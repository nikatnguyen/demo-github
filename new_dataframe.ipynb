# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
#Import csv files to read
sales_file_path = Path("sales_by_year.csv")
unemployment_file_path = Path("unemployment_by_year.csv")

#read csv files
sales_df = pd.read_csv(sales_file_path)
unemployment_df = pd.read_csv(unemployment_file_path)

# %%
sales_df.head()
# Out:
#    Unnamed: 0  Year  Total Restaurant Sales (in millions)  \
# 0           0  1992                                173468
# 1           1  1993                                185719
# 2           2  1994                                195025
# 3           3  1995                                202050
# 4           4  1996                                210149
#
#    Total Vehicle Units (in millions)
# 0                            157.294
# 1                            170.110
# 2                            184.775
# 3                            181.418
# 4                            185.455

# %%
unemployment_df.head()
# Out:
#    Year  Year.1  Yearly Unemployment Rate
# 0  1976    1976                  7.654154
# 1  1977    1977                  7.002357
# 2  1978    1978                  6.018049
# 3  1979    1979                  5.801846
# 4  1980    1980                  7.145776

# %%
#Cleaning up the dfs
sales_reduced_df = sales_df[["Year", "Total Restaurant Sales (in millions)", "Total Vehicle Units (in millions)"]]
sales_reduced_df
# Out:
#     Year  Total Restaurant Sales (in millions)  \
# 0   1992                                173468
# 1   1993                                185719
# 2   1994                                195025
# 3   1995                                202050
# 4   1996                                210149
# 5   1997                                223308
# 6   1998                                234940
# 7   1999                                244761
# 8   2000                                261098
# 9   2001                                272634
# 10  2002                                285492
# 11  2003                                302113
# 12  2004                                323584
# 13  2005                                343153
# 14  2006                                364280
# 15  2007                                381506
# 16  2008                                391048
# 17  2009                                388726
# 18  2010                                401956
# 19  2011                                428128
# 20  2012                                453168
# 21  2013                                471924
# 22  2014                                503023
# 23  2015                                546140
# 24  2016                                573325
# 25  2017                                604128
# 26  2018                                638601
# 27  2019                                674032
# 28  2020                                585413
# 29  2021                                762268
# 30  2022                                872976
# 31  2023                                640738
#
#     Total Vehicle Units (in millions)
# 0                             157.294
# 1                             170.110
# 2                             184.775
# 3                             181.418
# 4                             185.455
# 5                             185.981
# 6                             191.612
# 7                             208.978
# 8                             213.728
# 9                             209.665
# 10                            205.658
# 11                            203.597
# 12                            207.550
# 13                            209.354
# 14                            204.591
# 15                            197.545
# 16                            161.917
# 17                            127.217
# 18                            141.265
# 19                            156.589
# 20                            177.367
# 21                            190.585
# 22                            202.298
# 23                            214.285
# 24                            214.555
# 25                            210.762
# 26                            212.539
# 27                            209.865
# 28                            178.568
# 29                            184.906
# 30                            170.746
# 31                            127.655

# %%
unemployment_reduced_df = unemployment_df[["Year", "Yearly Unemployment Rate"]]
unemployment_reduced_df
# Out:
#     Year  Yearly Unemployment Rate
# 0   1976                  7.654154
# 1   1977                  7.002357
# 2   1978                  6.018049
# 3   1979                  5.801846
# 4   1980                  7.145776
# 5   1981                  7.606055
# 6   1982                  9.685206
# 7   1983                  9.612601
# 8   1984                  7.523955
# 9   1985                  7.186397
# 10  1986                  6.999297
# 11  1987                  6.190210
# 12  1988                  5.507966
# 13  1989                  5.271695
# 14  1990                  5.610555
# 15  1991                  6.837226
# 16  1992                  7.496179
# 17  1993                  6.924537
# 18  1994                  6.082763
# 19  1995                  5.585461
# 20  1996                  5.390603
# 21  1997                  4.937948
# 22  1998                  4.503026
# 23  1999                  4.211410
# 24  2000                  4.000340
# 25  2001                  4.730851
# 26  2002                  5.787072
# 27  2003                  5.988235
# 28  2004                  5.520400
# 29  2005                  5.103873
# 30  2006                  4.650016
# 31  2007                  4.614187
# 32  2008                  5.816485
# 33  2009                  9.240904
# 34  2010                  9.614778
# 35  2011                  8.952615
# 36  2012                  8.077364
# 37  2013                  7.364066
# 38  2014                  6.167384
# 39  2015                  5.272894
# 40  2016                  4.878238
# 41  2017                  4.352237
# 42  2018                  3.899414
# 43  2019                  3.670575
# 44  2020                  8.524608

# %%
#Merge the two cleaned dataframes
merged_df = pd.merge(unemployment_reduced_df, sales_reduced_df, on="Year", how="right")
merged_df
# Out:
#     Year  Yearly Unemployment Rate  Total Restaurant Sales (in millions)  \
# 0   1992                  7.496179                                173468
# 1   1993                  6.924537                                185719
# 2   1994                  6.082763                                195025
# 3   1995                  5.585461                                202050
# 4   1996                  5.390603                                210149
# 5   1997                  4.937948                                223308
# 6   1998                  4.503026                                234940
# 7   1999                  4.211410                                244761
# 8   2000                  4.000340                                261098
# 9   2001                  4.730851                                272634
# 10  2002                  5.787072                                285492
# 11  2003                  5.988235                                302113
# 12  2004                  5.520400                                323584
# 13  2005                  5.103873                                343153
# 14  2006                  4.650016                                364280
# 15  2007                  4.614187                                381506
# 16  2008                  5.816485                                391048
# 17  2009                  9.240904                                388726
# 18  2010                  9.614778                                401956
# 19  2011                  8.952615                                428128
# 20  2012                  8.077364                                453168
# 21  2013                  7.364066                                471924
# 22  2014                  6.167384                                503023
# 23  2015                  5.272894                                546140
# 24  2016                  4.878238                                573325
# 25  2017                  4.352237                                604128
# 26  2018                  3.899414                                638601
# 27  2019                  3.670575                                674032
# 28  2020                  8.524608                                585413
# 29  2021                       NaN                                762268
# 30  2022                       NaN                                872976
# 31  2023                       NaN                                640738
#
#     Total Vehicle Units (in millions)
# 0                             157.294
# 1                             170.110
# 2                             184.775
# 3                             181.418
# 4                             185.455
# 5                             185.981
# 6                             191.612
# 7                             208.978
# 8                             213.728
# 9                             209.665
# 10                            205.658
# 11                            203.597
# 12                            207.550
# 13                            209.354
# 14                            204.591
# 15                            197.545
# 16                            161.917
# 17                            127.217
# 18                            141.265
# 19                            156.589
# 20                            177.367
# 21                            190.585
# 22                            202.298
# 23                            214.285
# 24                            214.555
# 25                            210.762
# 26                            212.539
# 27                            209.865
# 28                            178.568
# 29                            184.906
# 30                            170.746
# 31                            127.655

# %%
#Drop any rows with NAN value
merged_df = merged_df.dropna(how='any')
merged_df
# Out:
#     Year  Yearly Unemployment Rate  Total Restaurant Sales (in millions)  \
# 0   1992                  7.496179                                173468
# 1   1993                  6.924537                                185719
# 2   1994                  6.082763                                195025
# 3   1995                  5.585461                                202050
# 4   1996                  5.390603                                210149
# 5   1997                  4.937948                                223308
# 6   1998                  4.503026                                234940
# 7   1999                  4.211410                                244761
# 8   2000                  4.000340                                261098
# 9   2001                  4.730851                                272634
# 10  2002                  5.787072                                285492
# 11  2003                  5.988235                                302113
# 12  2004                  5.520400                                323584
# 13  2005                  5.103873                                343153
# 14  2006                  4.650016                                364280
# 15  2007                  4.614187                                381506
# 16  2008                  5.816485                                391048
# 17  2009                  9.240904                                388726
# 18  2010                  9.614778                                401956
# 19  2011                  8.952615                                428128
# 20  2012                  8.077364                                453168
# 21  2013                  7.364066                                471924
# 22  2014                  6.167384                                503023
# 23  2015                  5.272894                                546140
# 24  2016                  4.878238                                573325
# 25  2017                  4.352237                                604128
# 26  2018                  3.899414                                638601
# 27  2019                  3.670575                                674032
# 28  2020                  8.524608                                585413
#
#     Total Vehicle Units (in millions)
# 0                             157.294
# 1                             170.110
# 2                             184.775
# 3                             181.418
# 4                             185.455
# 5                             185.981
# 6                             191.612
# 7                             208.978
# 8                             213.728
# 9                             209.665
# 10                            205.658
# 11                            203.597
# 12                            207.550
# 13                            209.354
# 14                            204.591
# 15                            197.545
# 16                            161.917
# 17                            127.217
# 18                            141.265
# 19                            156.589
# 20                            177.367
# 21                            190.585
# 22                            202.298
# 23                            214.285
# 24                            214.555
# 25                            210.762
# 26                            212.539
# 27                            209.865
# 28                            178.568

# %%
#Save as new csv file to make graphs
merged_df.to_csv('unemployment_and_sales.csv')

# %%
nojobyear = merged_df["Year"] 
nojobrate = merged_df["Yearly Unemployment Rate"] 

plt.title('Unemployment Rate %') 

plt.plot(nojobyear, nojobrate,linewidth=2, markersize=12) 
plt.xlabel('Years')
plt.ylabel('Unemployment Rate %')
plt.savefig('linechart')
plt.show()

# %%
plt.bar(merged_df['Year'],merged_df['Total Restaurant Sales (in millions)'])
plt.xlabel('Years')
plt.ylabel('Total Sales (In Millions)')
plt.title('Restaurant sales (In Millions)')
plt.savefig('restaurant_sales_year')
plt.show()

# %%
plt.bar(merged_df['Year'],merged_df['Total Vehicle Units (in millions)'],facecolor="red")
plt.xlabel('Years')
plt.ylabel('Units Sold (In Millions)')
plt.title('Vehicle Units Sold (In Millions)')
plt.savefig('vehicle_units_year')
plt.show()
